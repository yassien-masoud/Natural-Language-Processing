# %% [markdown]
# # Setup IBM Personality Insights

# %%
# Import Watson
from ibm_watson import PersonalityInsightsV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# Personality Insights apikey & url
apikey = 'put your apikey'
url = '                  '

# Authenticate to PI service
authenticator = IAMAuthenticator(apikey)
personality_insights = PersonalityInsightsV3(version='2017-10-13', authenticator=authenticator)
personality_insights.set_service_url(url)

# Fillering sort tweets function
def personality_anal(dicto, short_tweets=None, validate_dic=None):
    dic={}
    list_of_short_tweets = []
    for user_id, string in dicto.items():
        try:
            profile = personality_insights.profile(string, accept='application/json').get_result()
            dic[user_id]= profile
        except:
            list_of_short_tweets.append(user_id) 
            
    if short_tweets:
        return list_of_short_tweets
    
    if validate_dic:
        valid_dic = {}
        for user_id, string in dicto.items():
            if user_id not in list_of_short_tweets:
                valid_dic[user_id] = string
        return valid_dic                
    
    return dic

clean_dic = personality_anal(extr_tweets_strings, validate_dic=True)
final_dic = personality_anal(clean_dic)

# %% [markdown]
# ### Big Five Personality

# %%
def tweets_personality_df(dic):
    indexo = []
    personality=['Openness','Conscientiousness','Extraversion','Agreeableness','Emotional range']
    val = []
    for user_id, tweet_obj in dic.items():
        indexo.append(user_id)
        openness = tweet_obj['personality'][0]['percentile']
        Conscientiousness = tweet_obj['personality'][1]['percentile']
        Extraversion = tweet_obj['personality'][2]['percentile']
        Agreeableness = tweet_obj['personality'][3]['percentile']
        Emotional_range = tweet_obj['personality'][4]['percentile']
        val.append([openness, Conscientiousness, Extraversion, Agreeableness, Emotional_range])   
        
# convert to DataFram            
    df = pd.DataFrame(data = val, columns = personality, index = indexo)
    
    return df

personality=tweets_personality_df(final_dic)

# %%
# convert to list
personality_Openness=personality['Openness'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
personality_Openness_clear=detect_outlier(personality_Openness)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(personality_Openness_clear)
q1, q3= np.percentile(personality_Openness_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(personality_Openness_clear,cdf='norm')

# %%
# convert to list
personality_Conscientiousness=personality['Conscientiousness'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
personality_Conscientiousness_clear=detect_outlier(personality_Conscientiousness)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(personality_Conscientiousness_clear)
q1, q3= np.percentile(personality_Conscientiousness_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(personality_Conscientiousness_clear,cdf='norm')

# %%
# convert to list
personality_Extraversion=personality['Extraversion'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
personality_Extraversion_clear=detect_outlier(personality_Extraversion)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(personality_Extraversion_clear)
q1, q3= np.percentile(personality_Extraversion_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(personality_Extraversion_clear,cdf='norm')

# %%
# convert to list
personality_Agreeableness=personality['Agreeableness'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
personality_Agreeableness_clear=detect_outlier(personality_Agreeableness)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(personality_Agreeableness_clear)
q1, q3= np.percentile(personality_Agreeableness_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(personality_Agreeableness_clear,cdf='norm')

# %%
# convert to list
personality_Emotional=personality['Emotional range'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
personality_Emotional_clear=detect_outlier(personality_Emotional)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(personality_Emotional_clear)
q1, q3= np.percentile(personality_Emotional_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(personality_Emotional_clear,cdf='norm')

# %% [markdown]
# ### Values Factors

# %%
def tweets_personality_values_df(dic):
    indexo = []
    personality=['Conservation','Openness','Hedonism','Self-enhancement','Self-transcendence']
    val = []
    for user_id, tweet_obj in dic.items():
        indexo.append(user_id)
        Conservation = tweet_obj['values'][0]['percentile']
        Openness = tweet_obj['values'][1]['percentile']
        Hedonism = tweet_obj['values'][2]['percentile']
        Self_enhancement = tweet_obj['values'][3]['percentile']
        Self_transcendence = tweet_obj['values'][4]['percentile']
        val.append([Conservation, Openness, Hedonism, Self_enhancement, Self_transcendence])   
        
# convert to DataFram            
    df = pd.DataFrame(data = val, columns = personality, index = indexo)
    
    return df

values=tweets_personality_values_df(final_dic)

# %%
# convert to list
values_Conservation=values['Conservation'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
values_Conservation_clear=detect_outlier(values_Conservation)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(values_Conservation_clear)
q1, q3= np.percentile(values_Conservation_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(values_Conservation_clear,cdf='norm')

# %%
# convert to list
values_Openness=values['Openness'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
values_Openness_clear=detect_outlier(values_Openness)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(values_Openness_clear)
q1, q3= np.percentile(values_Openness_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(values_Openness_clear,cdf='norm')

# %%
# convert to list
values_Hedonism=values['Hedonism'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
values_Hedonism_clear=detect_outlier(values_Hedonism)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(values_Hedonism_clear)
q1, q3= np.percentile(values_Hedonism_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(values_Hedonism_clear,cdf='norm')

# %%
# convert to list
values_enhancement=values['Self-enhancement'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
values_enhancement_clear=detect_outlier(values_enhancement)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(values_enhancement_clear)
q1, q3= np.percentile(values_enhancement_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(values_enhancement_clear,cdf='norm')

# %%
# convert to list
values_transcendence=values['Self-transcendence'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
values_transcendence_clear=detect_outlier(values_transcendence)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(values_transcendence_clear)
q1, q3= np.percentile(values_transcendence_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(values_transcendence_clear,cdf='norm')

# %% [markdown]
# ### Needs Factors

# %%
def tweets_personality_needs_df(dic):
    indexo = []
    personality=['Challenge','Closeness','Curiosity','Excitement','Harmony','Ideal','Liberty','Love','Practicality','Self-expression','Stability','Structure']
    val = []
    for user_id, tweet_obj in dic.items():
        indexo.append(user_id)
        Challenge = tweet_obj['needs'][0]['percentile']
        Closeness = tweet_obj['needs'][1]['percentile']
        Curiosity = tweet_obj['needs'][2]['percentile']
        Excitement = tweet_obj['needs'][3]['percentile']
        Harmony = tweet_obj['needs'][4]['percentile']
        Ideal = tweet_obj['needs'][5]['percentile']
        Liberty = tweet_obj['needs'][6]['percentile']
        Love = tweet_obj['needs'][7]['percentile']
        Practicality = tweet_obj['needs'][8]['percentile']
        Self_expression = tweet_obj['needs'][9]['percentile']
        Stability = tweet_obj['needs'][10]['percentile']
        Structure = tweet_obj['needs'][11]['percentile']

        
        val.append([Challenge, Closeness, Curiosity, Excitement, Harmony, Ideal, Liberty, Love, Practicality, Self_expression, Stability, Structure])   

# convert to DataFram    
    df = pd.DataFrame(data = val, columns = personality, index = indexo)
    
    return df

needs=tweets_personality_needs_df(final_dic)

# %%
# convert to list
needs_Challenge=needs['Challenge'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
needs_Challenge_clear=detect_outlier(needs_Challenge)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(needs_Challenge_clear)
q1, q3= np.percentile(needs_Challenge_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(needs_Challenge_clear,cdf='norm')

# %%
# convert to list
needs_Closeness=needs['Closeness'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
needs_Closeness_clear=detect_outlier(needs_Closeness)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(needs_Closeness_clear)
q1, q3= np.percentile(needs_Closeness_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(needs_Closeness_clear,cdf='norm')

# %%
# convert to list
needs_Curiosity=needs['Curiosity'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
needs_Curiosity_clear=detect_outlier(needs_Curiosity)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(needs_Curiosity_clear)
q1, q3= np.percentile(needs_Curiosity_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(needs_Curiosity_clear,cdf='norm')

# %%
# convert to list
needs_Excitement=needs['Excitement'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
needs_Excitement_clear=detect_outlier(needs_Excitement)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(needs_Excitement_clear)
q1, q3= np.percentile(needs_Excitement_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(needs_Excitement_clear,cdf='norm')

# %%
# convert to list
needs_Harmony=needs['Harmony'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
needs_Harmony_clear=detect_outlier(needs_Harmony)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(needs_Harmony_clear)
q1, q3= np.percentile(needs_Harmony_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(needs_Harmony_clear,cdf='norm')

# %%
# convert to list
needs_Ideal=needs['Ideal'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
needs_Ideal_clear=detect_outlier(needs_Ideal)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(needs_Ideal_clear)
q1, q3= np.percentile(needs_Ideal_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(needs_Ideal_clear,cdf='norm')

# %%
# convert to list
needs_Liberty=needs['Liberty'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
needs_Liberty_clear=detect_outlier(needs_Liberty)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(needs_Liberty_clear)
q1, q3= np.percentile(needs_Liberty_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(needs_Liberty_clear,cdf='norm')

# %%
# convert to list
needs_Love=needs['Love'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
needs_Love_clear=detect_outlier(needs_Love)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(needs_Love_clear)
q1, q3= np.percentile(needs_Love_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(needs_Love_clear,cdf='norm')

# %%
# convert to list
needs_Practicality=needs['Practicality'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
needs_Practicality_clear=detect_outlier(needs_Practicality)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(needs_Practicality_clear)
q1, q3= np.percentile(needs_Practicality_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(needs_Practicality_clear,cdf='norm')

# %%
# convert to list
needs_expression=needs['Self-expression'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
needs_expression_clear=detect_outlier(needs_expression)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(needs_expression_clear)
q1, q3= np.percentile(needs_expression_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(needs_expression_clear,cdf='norm')

# %%
# convert to list
needs_Stability=needs['Stability'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
needs_Stability_clear=detect_outlier(needs_Stability)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(needs_Stability_clear)
q1, q3= np.percentile(needs_Stability_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(needs_Stability_clear,cdf='norm')

# %%
# convert to list
needs_Structure=needs['Structure'].values.tolist()

# Outliers function
outliers=[]
not_outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
        else:
            not_outliers.append(y)
    return not_outliers

# call function
needs_Structure_clear=detect_outlier(needs_Structure)

# Descriptive information( Calculate Median,q1, q3 and  IQR) 
Median=np.median(needs_Structure_clear)
q1, q3= np.percentile(needs_Structure_clear,[25,75])
IQR=q3-q1

# Kolmogorov-Smirnov’s Test
ks_test=stats.kstest(needs_Structure_clear,cdf='norm')
